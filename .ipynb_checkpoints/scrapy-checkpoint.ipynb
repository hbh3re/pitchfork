# %%
import pandas as pd

# %%
# is there anyway to scrape all reviews from pages that link to multiple reviews
# example: https://pitchfork.com/reviews/albums/bruce-springsteen-the-album-collection-vol-2-1987-1996/
reviews_csv = pd.read_csv('reviews_new.csv')

# %%
reviews_csv.head()
# Out:
#                                                album  \
# 0                                          Super Fly
# 1                    OIL OF EVERY PEARL’s UN-INSIDES
# 2  The Graduate (Original Motion Picture Soundtrack)
# 3                                     Stranger Fruit
# 4                                           Devotion
#
#                           artist  bnm  bnr          date  \
# 0                Curtis Mayfield    0    0    18 hrs ago
# 1                         SOPHIE    1    0  June 15 2018
# 2  Simon & Garfunkel,Dave Grusin    0    0  June 16 2018
# 3                   Zeal & Ardor    0    0  June 16 2018
# 4                     Laura Jean    0    0  June 15 2018
#
#                reviewer score  \
# 0   Mychal Denzel Smith   9.1
# 1          Sasha Geffen   8.6
# 2    Stephen M. Deusner   6.2
# 3  Grayson Haver Currin   7.3
# 4          Olivia Horn    6.8
#
#                                                  url
# 0  https://pitchfork.com/reviews/albums/curtis-ma...
# 1  https://pitchfork.com/reviews/albums/sophie-oi...
# 2  https://pitchfork.com/reviews/albums/simon-and...
# 3  https://pitchfork.com/reviews/albums/zeal-and-...
# 4  https://pitchfork.com/reviews/albums/laura-jea...

# %%
reviews_csv.shape
# Out:
# (20203, 8)

# %%
reviews_csv.isnull().sum()
# Out:
# album        13
# artist      731
# bnm           0
# bnr           0
# date          0
# reviewer      0
# score         0
# url           0
# dtype: int64

# %%
# 'Various Artists' albums were scraped as nans, so replaced here
reviews_csv['artist'] = reviews_csv['artist'].fillna('Various Artists')

# %%
# 13 album titles either weren't there or didn't scrape properly
# not entirely sure what to do about that...but not crucial to our goal
reviews_csv['album'] = reviews_csv['album'].fillna('N/A')

# %%
# clean up poor scraping of some artists names that led to repeats
# I think this actually arises in the case of those multi album reviews
# set_func = lambda x: ', '.join(set(x)) # function used to isolate artist name
# next line changes elements to list of strings and maps our function
# reviews_csv['artist'] = reviews_csv['artist'].str.split(',').map(set_func)
# oof this messes up artists that have a commma in their name

# %%
reviews_csv['date'][:10]
# Out:
# 0      18 hrs ago
# 1    June 15 2018
# 2    June 16 2018
# 3    June 16 2018
# 4    June 15 2018
# 5    June 16 2018
# 6    June 14 2018
# 7    June 15 2018
# 8    June 15 2018
# 9    June 14 2018
# Name: date, dtype: object

# %%
# fix dates that were scraped as '18 hours ago'
for i in [0]:
    reviews_csv.loc[i, 'date'] = 'June 17 2018'

# %%
# function used to changed date feature to datetime object
reviews_csv['date'] = pd.to_datetime(reviews_csv['date'].str.replace(' ', ''), format='%B%d%Y')

# %%
# split duplicate reviews into lists
# try splitting white space from artists and albums during scraping!!!
reviews_csv['score'] = reviews_csv['score'].str.split(',')
reviews_csv['album'] = reviews_csv['album'].str.split(r'(?<=\S),(?=\S)')
reviews_csv['artist'] = reviews_csv['artist'].str.split(r'(?<=\S),(?=\S)')

# %%
# length of 534
# maybe try this without changing artist col beforehand
bonus = reviews_csv[reviews_csv['score'].apply(lambda x: len(x) > 1)]
bonus
# Out:
#                                                    album  \
# 82             [Uptown Festival, Disco Gardens, Big Fun]
# 281                                           [6.9, 7.5]
# 308                  [8.7, 7.9, 8.5, 9.0, 7.8, 8.3, 8.5]
# 530                                           [9.0, 8.8]
# 574                            [6.7, 5.8, 6.3, 7.0, 7.3]
# 595                                           [7.4, 7.0]
# 624                                           [7.6, 7.3]
# 636                                           [7.0, 9.3]
# 643    [8.2, 8.2, 9.0, 6.5, 6.1, 7.3, 4.7, 6.7, 5.9, ...
# 658                                           [7.6, 8.3]
# 723                                      [8.2, 7.8, 8.6]
# 793                                 [8.5, 8.0, 7.0, 8.9]
# 799                                      [7.6, 7.1, 7.9]
# 832                                           [8.5, 7.6]
# 899                                           [7.3, 7.6]
# 935                                           [6.6, 7.0]
# 1031                                          [8.5, 8.0]
# 1052                                          [7.0, 6.6]
# 1077                                       [9.5, 10, 10]
# 1123                                          [6.7, 8.3]
# 1144                                     [8.7, 8.2, 7.0]
# 1147                                          [7.6, 7.9]
# 1324                                     [8.5, 7.0, 8.0]
# 1357                                          [7.4, 7.4]
# 1420                                          [7.2, 7.4]
# 1421                                          [8.0, 6.8]
# 1499                                          [8.2, 8.0]
# ...                                                  ...
# 17226                                         [6.7, 8.0]
# 17340                                    [8.4, 8.6, 7.8]
# 17384                                         [7.5, 5.5]
# 17386                                         [9.0, 9.6]
# 17403                                         [9.7, 8.8]
# 17410                               [9.5, 8.3, 5.7, 6.8]
# 17442                                         [3.9, 6.2]
# 17474                                         [8.7, 6.9]
# 17491                                    [4.9, 6.8, 6.9]
# 17507                                         [7.7, 6.9]
# 17633                                    [7.3, 6.2, 8.7]
# 17746                                         [7.9, 8.4]
# 17833                                         [8.2, 7.8]
# 17991                                         [8.6, 6.5]
# 18043                                         [9.0, 8.6]
# 18066                                         [5.9, 5.6]
# 18148                                         [3.8, 9.5]
# 18149                                         [7.6, 7.8]
# 18235                                         [7.2, 8.3]
# 18636                                         [7.0, 7.0]
# 18666                                     [6.9, 9.2, 10]
# 18709                                         [8.3, 9.1]
# 18780                                         [7.7, 8.2]
# 18802                                         [9.0, 9.0]
# 19017                                         [7.5, 8.3]
# 19401                                         [9.0, 9.6]
# 19578                                         [9.5, 3.5]
# 19762                                         [1.5, 7.8]
# 19945                                         [6.8, 6.8]
# 19960                                         [7.8, 7.8]
#
#                                                      url
# 82     https://pitchfork.com/reviews/albums/shalamar-...
# 97     https://pitchfork.com/reviews/albums/bruce-spr...
# 150    https://pitchfork.com/reviews/albums/rae-sremm...
# 178    https://pitchfork.com/reviews/albums/dj-healer...
# 281    https://pitchfork.com/reviews/albums/the-cars-...
# 308    https://pitchfork.com/reviews/albums/tom-waits...
# 530    https://pitchfork.com/reviews/albums/todd-rund...
# 574    https://pitchfork.com/reviews/albums/the-jazz-...
# 595    https://pitchfork.com/reviews/albums/onyx-coll...
# 624    https://pitchfork.com/reviews/albums/chris-sta...
# 636    https://pitchfork.com/reviews/albums/wilco-amb...
# 643    https://pitchfork.com/reviews/albums/weird-al-...
# 658    https://pitchfork.com/reviews/albums/krallice-...
# 723    https://pitchfork.com/reviews/albums/pharoah-s...
# 793    https://pitchfork.com/reviews/albums/in-the-ci...
# ['7.4', '7.0']
# 16 15 16
# ['“Weird Al” Yankovic', '“Weird Al” Yankovic', '“Weird Al” Yankovic', '“Weird Al” Yankovic', '“Weird Al” Yankovic', '“Weird Al” Yankovic', '“Weird Al” Yankovic', '“Weird Al” Yankovic', '“Weird Al” Yankovic', '“Weird Al” Yankovic', '“Weird Al” Yankovic', '“Weird Al” Yankovic', '“Weird Al” Yankovic', '“Weird Al” Yankovic', '“Weird Al” Yankovic', '“Weird Al” Yankovic']
# ['Squeeze Box: The Complete Works of “Weird Al” Yankovic', '“Weird Al” Yankovic', '“Weird Al” Yankovic in 3-D', 'Dare to Be Stupid', 'Polka Party!', 'Even Worse', 'UHF Original Motion Picture Soundtrack and Other Stuff ,Off the Deep End', 'Alapalooza', 'Bad Hair Day', 'Running With Scissors', 'Poodle Hat', 'Straight Outta Lynwood', 'Alpocalypse', 'Mandatory Fun', 'Medium Rarities']
# ['8.2', '8.2', '9.0', '6.5', '6.1', '7.3', '4.7', '6.7', '5.9', '6.8', '7.2', '6.5', '7.3', '7.4', '7.8', '5.7']
# 2 1 2
# ['Laraaji', 'Laraaji']
# ['Sun Gong ,Bring on the Sun']
# ['7.3', '7.6']
# 1 2 2
# ['Various Artists']
# ['Welcome to Paradise: Italian Dream House 1989-93 Vol 1', 'Welcome to Paradise: Italian Dream House 1989-93 Vol 2']
# ['8.2', '8.0']
# 5 3 3
# ['Yoko Ono', 'John Lennon', 'Yoko Ono', 'John Lennon', 'Yoko Ono']
# ['Unfinished Music No. 1: Two Virgins', 'Unfinished Music No. 2: Life With the Lions', 'Yoko Ono Plastic Ono Band']
# ['6.8', '5.9', '9.1']
# 4 2 2
# ['Sun Ra', 'Merzbow', 'Sun Ra', 'Merzbow']
# ['Strange City (CD)', 'Strange City (LP)']
# ['7.3', '6.7']
# 1 2 2
# ['Various Artists']
# ["Sound Signature Presents: These Songs That Should've Been Out on Wax By Now - Part One", "Sound Signature Presents: These Songs That Should've Been Out on Wax By Now - Part Two"]
# ['7.4', '7.6']
# 4 2 2
# ['Robert Glasper', 'Miles Davis', 'Robert Glasper', 'Miles Davis']
# ['Miles Ahead OST', "Everything's Beautiful"]
# ['6.2', '7.4']
# 1 2 2
# ['Various Artists']
# ['Wake Up You!: The Rise & Fall of Nigerian Rock 1972-1977 Vol. 1', 'Wake Up You!: The Rise & Fall of Nigerian Rock 1972-1977 Vol. 2']
# ['7.5', '7.3']
# 12 9 9
# ['Cluster', 'Cluster', 'Cluster', 'Cluster', 'Cluster', 'Brian Eno', 'Brian Eno', 'Dieter Moebius', 'Roedelius', 'Cluster', 'Cluster', 'Cluster']
# ['Cluster 71', 'Cluster II', 'Zuckerzeit', 'Sowiesoso', 'Cluster & Eno', 'After the Heat', 'Grosses Wasser', 'Curiosum', 'Konzerte 1972/1977']
# ['8.5', '7.7', '9.0', '9.2', '8.7', '9.0', '7.6', '7.4', '7.3']
# 1 2 2
# ['Various Artists']
# ['Punk 45: Extermination Nights in the Sixth City', 'Punk 45: Burn Rubber City, Burn!']
# ['8.0', '7.7']
# 1 2 2
# ['Various Artists']
# ['Back From the Grave Vol. 9', 'Back From the Grave Vol. 10']
# ['7.6', '7.9']

# %%
for idx, row in bonus.head().iterrows():
    print(row)
    for i in range(len(row['album'])):
        print({'album': row['album'][i], 'artist': row['artist'], 'bnm': row['bnm'],
               'bnr': row['bnr'], 'date': row['date'], 'reviewer': row['reviewer'],
               'score': row['score'][i], 'url': row['url']})
# Out:
# album               [Uptown Festival, Disco Gardens, Big Fun]
# artist                                               Shalamar
# bnm                                                         0
# bnr                                                         0
# date                                      2018-05-26 00:00:00
# reviewer                                       Ernest Wilkins
# score                                         [4.2, 7.0, 7.6]
# url         https://pitchfork.com/reviews/albums/shalamar-...
# Name: 82, dtype: object
# {'album': 'Uptown Festival', 'artist': 'Shalamar', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-05-26 00:00:00'), 'reviewer': 'Ernest Wilkins', 'score': '4.2', 'url': 'https://pitchfork.com/reviews/albums/shalamar-uptown-festival-disco-gardens-big-fun/'}
# {'album': 'Disco Gardens', 'artist': 'Shalamar', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-05-26 00:00:00'), 'reviewer': 'Ernest Wilkins', 'score': '7.0', 'url': 'https://pitchfork.com/reviews/albums/shalamar-uptown-festival-disco-gardens-big-fun/'}
# {'album': 'Big Fun', 'artist': 'Shalamar', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-05-26 00:00:00'), 'reviewer': 'Ernest Wilkins', 'score': '7.6', 'url': 'https://pitchfork.com/reviews/albums/shalamar-uptown-festival-disco-gardens-big-fun/'}
# album       [Tunnel of Love, Chimes of Freedom EP, Human T...
# artist                                      Bruce Springsteen
# bnm                                                         0
# bnr                                                         0
# date                                      2018-05-19 00:00:00
# reviewer                                         Sam Sodomsky
# score                     [9.5, 6.4, 5.8, 6.8, 6.1, 7.6, 5.4]
# url         https://pitchfork.com/reviews/albums/bruce-spr...
# Name: 97, dtype: object
# {'album': 'Tunnel of Love', 'artist': 'Bruce Springsteen', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-05-19 00:00:00'), 'reviewer': 'Sam Sodomsky', 'score': '9.5', 'url': 'https://pitchfork.com/reviews/albums/bruce-springsteen-the-album-collection-vol-2-1987-1996/'}
# {'album': 'Chimes of Freedom EP', 'artist': 'Bruce Springsteen', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-05-19 00:00:00'), 'reviewer': 'Sam Sodomsky', 'score': '6.4', 'url': 'https://pitchfork.com/reviews/albums/bruce-springsteen-the-album-collection-vol-2-1987-1996/'}
# {'album': 'Human Touch', 'artist': 'Bruce Springsteen', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-05-19 00:00:00'), 'reviewer': 'Sam Sodomsky', 'score': '5.8', 'url': 'https://pitchfork.com/reviews/albums/bruce-springsteen-the-album-collection-vol-2-1987-1996/'}
# {'album': 'Lucky Town', 'artist': 'Bruce Springsteen', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-05-19 00:00:00'), 'reviewer': 'Sam Sodomsky', 'score': '6.8', 'url': 'https://pitchfork.com/reviews/albums/bruce-springsteen-the-album-collection-vol-2-1987-1996/'}
# {'album': 'In Concert/MTV Plugged', 'artist': 'Bruce Springsteen', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-05-19 00:00:00'), 'reviewer': 'Sam Sodomsky', 'score': '6.1', 'url': 'https://pitchfork.com/reviews/albums/bruce-springsteen-the-album-collection-vol-2-1987-1996/'}
# {'album': 'The Ghost of Tom Joad', 'artist': 'Bruce Springsteen', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-05-19 00:00:00'), 'reviewer': 'Sam Sodomsky', 'score': '7.6', 'url': 'https://pitchfork.com/reviews/albums/bruce-springsteen-the-album-collection-vol-2-1987-1996/'}
# {'album': 'Blood Brothers EP', 'artist': 'Bruce Springsteen', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-05-19 00:00:00'), 'reviewer': 'Sam Sodomsky', 'score': '5.4', 'url': 'https://pitchfork.com/reviews/albums/bruce-springsteen-the-album-collection-vol-2-1987-1996/'}
# album                            [SR3MM , Swaecation, Jxmtro]
# artist                     Swae Lee, Slim Jxmmi, Rae Sremmurd
# bnm                                                         0
# bnr                                                         0
# date                                      2018-05-08 00:00:00
# reviewer                                       Sheldon Pearce
# score                                         [8.1, 7.4, 7.6]
# url         https://pitchfork.com/reviews/albums/rae-sremm...
# Name: 150, dtype: object
# {'album': 'SR3MM ', 'artist': 'Swae Lee, Slim Jxmmi, Rae Sremmurd', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-05-08 00:00:00'), 'reviewer': 'Sheldon Pearce', 'score': '8.1', 'url': 'https://pitchfork.com/reviews/albums/rae-sremmurd-swae-lee-slim-jxmmi-sr3mm/'}
# {'album': 'Swaecation', 'artist': 'Swae Lee, Slim Jxmmi, Rae Sremmurd', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-05-08 00:00:00'), 'reviewer': 'Sheldon Pearce', 'score': '7.4', 'url': 'https://pitchfork.com/reviews/albums/rae-sremmurd-swae-lee-slim-jxmmi-sr3mm/'}
# {'album': 'Jxmtro', 'artist': 'Swae Lee, Slim Jxmmi, Rae Sremmurd', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-05-08 00:00:00'), 'reviewer': 'Sheldon Pearce', 'score': '7.6', 'url': 'https://pitchfork.com/reviews/albums/rae-sremmurd-swae-lee-slim-jxmmi-sr3mm/'}
# album                 [Nothing 2 Loose, Mudshadow Propaganda]
# artist                      DJ Healer, Prime Minister of Doom
# bnm                                                         0
# bnr                                                         0
# date                                      2018-05-02 00:00:00
# reviewer                                          Drew Gaerig
# score                                              [8.2, 8.0]
# url         https://pitchfork.com/reviews/albums/dj-healer...
# Name: 178, dtype: object
# {'album': 'Nothing 2 Loose', 'artist': 'DJ Healer, Prime Minister of Doom', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-05-02 00:00:00'), 'reviewer': 'Drew Gaerig', 'score': '8.2', 'url': 'https://pitchfork.com/reviews/albums/dj-healer-prime-minister-of-doom-dj-healer-nothing-2-loose-prime-minister-of-doom-mudshadow-propaganda/'}
# {'album': 'Mudshadow Propaganda', 'artist': 'DJ Healer, Prime Minister of Doom', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-05-02 00:00:00'), 'reviewer': 'Drew Gaerig', 'score': '8.0', 'url': 'https://pitchfork.com/reviews/albums/dj-healer-prime-minister-of-doom-dj-healer-nothing-2-loose-prime-minister-of-doom-mudshadow-propaganda/'}
# album                           [Shake It Up, Heartbeat City]
# artist                                               The Cars
# bnm                                                         0
# bnr                                                         0
# date                                      2018-03-31 00:00:00
# reviewer                                          Alfred Soto
# score                                              [6.9, 7.5]
# url         https://pitchfork.com/reviews/albums/the-cars-...
# Name: 281, dtype: object
# {'album': 'Shake It Up', 'artist': 'The Cars', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-03-31 00:00:00'), 'reviewer': 'Alfred Soto', 'score': '6.9', 'url': 'https://pitchfork.com/reviews/albums/the-cars-shake-it-up-heartbeat-city/'}
# {'album': 'Heartbeat City', 'artist': 'The Cars', 'bnm': 0, 'bnr': 0, 'date': Timestamp('2018-03-31 00:00:00'), 'reviewer': 'Alfred Soto', 'score': '7.5', 'url': 'https://pitchfork.com/reviews/albums/the-cars-shake-it-up-heartbeat-city/'}

# %%
import matplotlib.pyplot as plt
# might have to remove their 'Sunday classics' reviews to get the fair picture
plt.plot(reviews_csv['date'], reviews_csv['score'].astype(float))
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-31f5a306eeab> in <module>()
#       1 import matplotlib.pyplot as plt
#       2 # might have to remove their 'Sunday classics' reviews to get the fair picture
# ----> 3 plt.plot(reviews_csv['date'], reviews_csv['score'].astype(float))
#       4 plt.show()
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, **kwargs)
#    3455
#    3456     def astype(self, dtype, **kwargs):
# -> 3457         return self.apply('astype', dtype=dtype, **kwargs)
#    3458
#    3459     def convert(self, **kwargs):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#    3322
#    3323             kwargs['mgr'] = self
# -> 3324             applied = getattr(b, f)(**kwargs)
#    3325             result_blocks = _extend_blocks(applied, result_blocks)
#    3326
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in astype(self, dtype, copy, errors, values, **kwargs)
#     542     def astype(self, dtype, copy=False, errors='raise', values=None, **kwargs):
#     543         return self._astype(dtype, copy=copy, errors=errors, values=values,
# --> 544                             **kwargs)
#     545
#     546     def _astype(self, dtype, copy=False, errors='raise', values=None,
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in _astype(self, dtype, copy, errors, values, klass, mgr, **kwargs)
#     623
#     624                 # _astype_nansafe works fine with 1-d only
# --> 625                 values = astype_nansafe(values.ravel(), dtype, copy=True)
#     626                 values = values.reshape(self.shape)
#     627
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/dtypes/cast.py in astype_nansafe(arr, dtype, copy)
#     701
#     702     if copy:
# --> 703         return arr.astype(dtype)
#     704     return arr.view(dtype)
#     705
#
# ValueError: could not convert string to float: '7.8,7.8'

# %%
# reviews_csv['month'] = reviews_csv['date'].dt.month
# reviews_csv['year']  = reviews_csv['date'].dt.year

# %%
reviews_csv.set_index(reviews_csv['date']).resample('M').mean().plot()
plt.title('Mean over time')
plt.show()

# %%
reviews_csv.set_index(reviews_csv['date']).resample('M').var().plot()
plt.title('Variance over time')
plt.show()

# %%
# reviews_csv.set_index(reviews_csv['date']).truncate(after='2009-01-06')

# %%
reviews_since2010 = reviews_csv.iloc[:10024]

# %%
# an increase of 0.5 is notable when considering 1100-1200 reviews per year
reviews_since2010.set_index(reviews_since2010['date']).resample('M').mean().plot()
# plt.plot(np.unique(x), np.poly1d(np.polyfit(x, y, 1))(np.unique(x)))
plt.title('Mean per month, since 2010')
plt.show()

# %%
reviews_since2010.set_index(reviews_since2010['date']).resample('M').var().plot()
plt.title('Variance per month, since 2010')
plt.show()

# %%
# what reviews happened towards the end of 2011???
reviews_csv.loc[(reviews_csv['date'].dt.month==12) & (reviews_csv['date'].dt.year==2011) & (reviews_csv['score'] < 5)]
# I guess Pitchfork didn't like the two rap albums that defined my 9th grade year

# %%
# definitely the most exciting and telling graph
# might be affected by number of reviews per year?
reviews_csv.set_index(reviews_csv['date']).resample('Y').var().plot()
plt.title('Variance per year')
plt.show()

# %%
# reviews per year has been pretty constant since 2003
reviews_csv.set_index(reviews_csv['date']).resample('Y').count()['score']

# %%
rev_count = reviews_csv.set_index(reviews_csv['date']).resample('Y').count()['score']

# %%
import numpy as np
np.mean(list(rev_count[6:19])) / 365
# average 3.26 reviews per day since

# %%
# last two years (2016, 2017) had the highest yearly means ever, with 2018 currently on pace to be third (re-check?)
reviews_csv.set_index(reviews_csv['date']).resample('Y').mean()

# %%
# now want to see a distribution of scores
reviews_csv.hist(column='score')
plt.show()

# %%
# histograms each year are pretty consistent
for idx, df, in reviews_csv.set_index(reviews_csv['date']).groupby(pd.Grouper(freq='Y')):
    df.hist(column='score')
plt.show()

# %%
# most common reviewers (200 or more)
common_reviewers = reviews_csv.groupby('reviewer').filter(lambda x: len(x) > 200)
mean_reviewer_scores = common_reviewers.groupby('reviewer').mean()
reviewer_counts = common_reviewers.groupby('reviewer').count()['artist']
reviewers_df = pd.concat([mean_reviewer_scores, reviewer_counts], axis=1).sort_values(by='score', ascending=False)
reviewers_df.columns = ['avg_score', 'num_reviews']
reviewers_df

# %%
# most common artists reviewed
# reviews_csv['artist'].value_counts().drop('Various Artists')
common_artists = reviews_csv.groupby('artist').filter(lambda x: len(x) > 2)[reviews_csv['artist'] != 'Various Artists']
artist_means = common_artists.groupby('artist').mean()

# %%
# can link to full list of results in article and only mention notables like alt-J
artist_means.sort_values('score', ascending=False)

# %%
text_csv = pd.read_csv('pitchfork_reviews_text.csv')

# %%
text_csv.head()
# Out:
#    score         date            album          artist              reviewer  \
# 0    8.0   14 hrs ago           Vibras        J Balvin  Matthew  Ismael Ruiz
# 1    7.9  May 29 2018  Midnight Marker      Shy Layers      Philip Sherburne
# 2    7.8  May 29 2018    Paz & Amor EP      DJ Lilocox             Andy Beta
# 3    7.5  May 29 2018          Sink EP  Sudan Archives            Jenn Pelly
# 4    6.7  May 29 2018          Testing      A$AP Rocky        Stephen Kearse
#
#                                                 text  \
# 0  On his first trips to America as a precocious ...
# 1  JD Walsh’s   as  , two years ago, came laced w...
# 2  In dance music, small and localized scenes rar...
# 3   is a 24-year-old violinist with “too much swa...
# 4  In late May,     to a glass cell fitted with c...
#
#                                                  url  bnm
# 0  https://pitchfork.com/reviews/albums/j-balvin-...    0
# 1  https://pitchfork.com/reviews/albums/shy-layer...    0
# 2  https://pitchfork.com/reviews/albums/dj-liloco...    0
# 3  https://pitchfork.com/reviews/albums/sudan-arc...    0
# 4  https://pitchfork.com/reviews/albums/asap-rock...    0

# %%
# 'Various Artists' albums were scraped as nans, so replaced here
text_csv['artist'] = text_csv['artist'].fillna('Various Artists')

# 13 album titles either weren't there or didn't scrape properly
# not entirely sure what to do about that...but not crucial to our goal
text_csv['album'] = text_csv['album'].fillna('N/A')

# %%
text_csv.shape
# Out:
# (14730, 8)

# %%
text_csv.isnull().sum()
# Out:
# score       0
# date        0
# album       0
# artist      0
# reviewer    0
# text        6
# url         0
# bnm         0
# dtype: int64

# %%
text_csv.dropna(inplace=True) # drop reviews with no text

# %%
# text pre-processing: remove numbers and artist names

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import linear_model
from sklearn.model_selection import train_test_split

tfidf = TfidfVectorizer(max_df=0.95, min_df=0.001) # don't need stopwords with max_df cutoff
X = tfidf.fit_transform(text_csv['text'])
y = text_csv.score

x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

model = linear_model.Ridge(normalize=True)
model.fit(x_train, y_train)

print(model.score(x_test, y_test))
# Out:
# [0.001, 0.0001] 0.414327558502

# %%
preds = model.predict(x_test)

# %%
from sklearn import metrics

print(metrics.mean_absolute_error(y_test, preds))
# Out:
# 0.624387209124

# %%
# as you can see, predictions look very consistent and with a low variance
# maybe this shows the low variance pattern of Pitchfock, or maybe it's the model
# we can't really say anything definitive but it is still interesting

preds[:10]
# Out:
# array([ 6.97107788,  6.30537515,  6.94883495,  6.89909768,  7.41958409,
#         6.76684966,  6.20090309,  7.06832482,  7.18660331,  6.7490292 ])

# %%
y_test[:10]
# Out:
# 9762     6.4
# 4764     5.6
# 235      6.0
# 6327     6.8
# 11713    7.9
# 9663     6.8
# 8860     4.0
# 1699     7.4
# 1981     6.7
# 7895     7.9
# Name: score, dtype: float64

# %%
pd.Series(preds).var() # learned a pretty consistent distribution
# Out:
# 0.3239332608496834

# %%
# next step is to create a binary classifier of good vs. bad reviews
# perhaps add a third class for good, bad, neutral

# perhaps define the cutoff based on Pitchfork's standard and find the mean (median?) score to delineate good vs. bad

# also go back and do text pre-processing

# %%
# has the standard for best new music changed since it started in 2003?
# also! graph best new music per reviews each year to see if the frequency has increased

best_new_music = text_csv[text_csv['bnm'] == 1]

# %%
best_new_music.shape
# Out:
# (945, 8)

# %%
best_new_music.head()
# Out:
#     score         date        album         artist          reviewer  \
# 19    8.3  May 25 2018      Daytona        Pusha-T  Paul A. Thompson
# 48    8.6  May 17 2018       Compro      Skee Mask       Ezra Marcus
# 56    8.5  May 16 2018      Die Lit  Playboi Carti    Evan Rytlewski
# 63    8.9  May 11 2018            7    Beach House     Jayson Greene
# 83    8.3  May 10 2018  Singularity    Jon Hopkins        Brian Howe
#
#                                                  text  \
# 19  Sometimes the conveyor belt of hype and rumor ...
# 48  Revivalism and dance culture aren’t a great ma...
# 56  Being a great rapper has never been a prerequi...
# 63  Over six albums, Victoria Legrand and Alex Sca...
# 83  Jon Hopkins is playing God. That much is clear...
#
#                                                   url  bnm
# 19  https://pitchfork.com/reviews/albums/pusha-t-d...    1
# 48  https://pitchfork.com/reviews/albums/skee-mask...    1
# 56  https://pitchfork.com/reviews/albums/playboi-c...    1
# 63  https://pitchfork.com/reviews/albums/beach-hou...    1
# 83  https://pitchfork.com/reviews/albums/jon-hopki...    1

# %%
best_new_music['date'] = pd.to_datetime(best_new_music['date'].str.replace(' ', ''), format='%B%d%Y')
# Out:
# /Users/henryharris/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
import matplotlib.pyplot as plt

plt.plot(best_new_music['date'], best_new_music['score'])
plt.show()

# %%
# investigate the outliers
# ooo this breaks when there are multiple pages on one review
# should only track best new music, not best new reissue

best_new_music[best_new_music['score'] < 8]
# Out:
#        score       date                                album  \
# 576      7.0 2017-12-06                                 A.M.
# 1838     6.8 2016-12-05  Unfinished Music No. 1: Two Virgins
# 2057     7.4 2016-10-04             Dr. Ragtime and His Pals
# 3382     7.8 2015-09-07    Challenge for a Civilized Society
# 3650     7.6 2015-06-10                       The Real Thing
# 4518     6.5 2014-09-04                                  M83
# 5965     7.2 2013-06-13              The Incomplete Triangle
# 6975     7.0 2012-08-07                            Nocturama
# 8595     6.7 2011-03-24                                Queen
# 9681     5.2 2010-04-21               Incredible String Band
# 10058    7.8 2009-12-11                           Neil Young
# 10801    7.3 2009-05-06                 From Her to Eternity
# 10873    5.4 2009-04-16     Pablo Honey: Collector's Edition
#
#                                                   artist            reviewer  \
# 576                                          Wilco,Wilco  Stephen M. Deusner
# 1838   Yoko Ono,John Lennon,Yoko Ono,John Lennon,Yoko...   Seth Colter Walls
# 2057   Jack Rose,Jack Rose,Jack Rose,Jack Rose,Jack R...        Sam Sodomsky
# 3382                                     Unwound,Unwound      Evan Rytlewski
# 3650                         Faith No More,Faith No More       Stuart Berman
# 4518                                 M83,M83,M83,M83,M83          Matt LeMay
# 5965     Lansing-Dreiden,Lansing-Dreiden,Lansing-Dreiden        Miles Raymer
# 6975   Nick Cave & the Bad Seeds,Nick Cave & the Bad ...       Stuart Berman
# 8595                 Queen,Queen,Queen,Queen,Queen,Queen     Dominique Leone
# 9681   Incredible String Band,Incredible String Band,...       Andrew Gaerig
# 10058        Neil Young,Neil Young,Neil Young,Neil Young     Mark Richardson
# 10801  Nick Cave & the Bad Seeds,Nick Cave & the Bad ...       Stuart Berman
# 10873                      Radiohead,Radiohead,Radiohead    Scott Plagenhoef
#
#                                                     text  \
# 576    The nuclear detonation of   launched an alt-co...
# 1838   Courting confusion is part of the job descript...
# 2057   The fiery, pastoral steel-string guitar music ...
# 3382   By the late '90s, Unwound were asking themselv...
# 3650   Judging from crowd reactions at last month's F...
# 4518   It’s hard to imagine a project better suited f...
# 5965   When   first rose to indie-world notoriety in ...
# 6975   At the turn of millennium, old-school   fans h...
# 8595   Fucking Queen. For all their reported bombast,...
# 9681   In the liner notes to these carefully packaged...
# 10058  It's getting hard to keep up with Neil Young. ...
# 10801  Unlike his predecessors in the fraternal order...
# 10873  When Capitol released a few different shortcut...
#
#                                                      url  bnm
# 576    https://pitchfork.com/reviews/albums/wilco-amb...    1
# 1838   https://pitchfork.com/reviews/albums/22393-unf...    1
# 2057   https://pitchfork.com/reviews/albums/22362-red...    1
# 3382   https://pitchfork.com/reviews/albums/20891-emp...    1
# 3650   https://pitchfork.com/reviews/albums/20606-fai...    1
# 4518   https://pitchfork.com/reviews/albums/19775-m83...    1
# 5965   https://pitchfork.com/reviews/albums/18167-lan...    1
# 6975   https://pitchfork.com/reviews/albums/16884-rei...    1
# 8595   https://pitchfork.com/reviews/albums/15221-rei...    1
# 9681   https://pitchfork.com/reviews/albums/14153-the...    1
# 10058  https://pitchfork.com/reviews/albums/13771-nei...    1
# 10801  https://pitchfork.com/reviews/albums/12949-fro...    1
# 10873  https://pitchfork.com/reviews/albums/12938-pab...    1
